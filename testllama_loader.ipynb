# %%
# !pip install -U llama-index --upgrade --no-cache-dir --force-reinstall
# Out:
# WARNING: Ignoring invalid distribution ~andas (/Users/wonjimin/pointchecker-genai-python/.conda/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~andas (/Users/wonjimin/pointchecker-genai-python/.conda/lib/python3.11/site-packages)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.8/114.8 kB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 366.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 131.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 230.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 71.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.2/390.2 kB 90.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 73.6 MB/s eta 0:00:00
# ...

# %%
# !pip install llama-parse python-dotenv
# Out:
# WARNING: Ignoring invalid distribution ~andas (/Users/wonjimin/pointchecker-genai-python/.conda/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~andas (/Users/wonjimin/pointchecker-genai-python/.conda/lib/python3.11/site-packages)
# ...
#   Using cached pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
# WARNING: Ignoring invalid distribution ~andas (/Users/wonjimin/pointchecker-genai-python/.conda/lib/python3.11/site-packages)
# ...
# WARNING: Ignoring invalid distribution ~andas (/Users/wonjimin/pointchecker-genai-python/.conda/lib/python3.11/site-packages)
# ...
# WARNING: Ignoring invalid distribution ~andas (/Users/wonjimin/pointchecker-genai-python/.conda/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~andas (/Users/wonjimin/pointchecker-genai-python/.conda/lib/python3.11/site-packages)
# ...

# %%
import os
from dotenv import load_dotenv
load_dotenv()

OPENAI_API_KEY = os.environ["OPENAI_API_KEY"] 
COHERE_API_KEY = os.environ["COHERE_API_KEY"] 
LLAMAIDX_API_KEY = os.environ["LLAMAIDX_API_KEY"]

# %%
import nest_asyncio

nest_asyncio.apply()

from llama_parse import LlamaParse
from llama_index.core import SimpleDirectoryReader

parser = LlamaParse(
    api_key=LLAMAIDX_API_KEY,  # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type="markdown",  # "markdown" and "text" are available
    verbose=True,
)

file_extractor = {".pdf": parser}
documents = SimpleDirectoryReader(
    "./data", file_extractor=file_extractor
).load_data()

print(documents[0].text[0:1000])
# Out:
# Started parsing the file under job_id 7ec1e5b6-8a18-40b9-be25-9188453cbbc6
# # PTTLNG Nong Fab LNG Receiving Terminal Project
#
# # Invitation to Bid
#
# # Engineering, Procurement, Construction and Commissioning (EPCC) Services
#
# # Part B Form and Conditions of Contract
#
# Revision 0, March 2017
# ---
# # PTTLNG Nong Fab LNG Receiving Terminal Project Invitation to Bid EPCC Services Part B, Form and Conditions of Contract Rev. 0, Mar. 2017
#
# # Part B Form and Conditions of Contract
#
# # INDEX
#
# |ARTICLE 1|DEFINITIONS|
# |---|---|
# |ARTICLE 2|SCOPE OF WORK|
# |ARTICLE 3|CONTRACT PRICE|
# |ARTICLE 4|TERMS OF PAYMENT|
# |ARTICLE 5|CHANGES IN THE WORK|
# |ARTICLE 6|TAXES AND DUTIES|
# |ARTICLE 7|PERFORMANCE SECURITY|
# |ARTICLE 8|REMUNERATION|
# |ARTICLE 9|INDEPENDENT CONTRACTOR|
# |ARTICLE 10|INFORMATION PROVIDED BY PTTLNG|
# |ARTICLE 11|PTTLNG PARTICIPATION AND APPROVALS|
# |ARTICLE 12|WORK PROGRAMME AND COORDINATION PROCEDURE|
# |ARTICLE 13|PROCUREMENT|
# ...

# %%
print(documents[0].text[18000:20000])
# Out:
# urement, all supplies of equipment and other items, site preparation, construction, erection, pre-commissioning, commissioning, testing, all other services such as training, manhours, expenses, overhead, all other direct or indirect cost, profit, etc. and all taxes, duties, customs duties, fees, permits and the like, a fixed lump sum (hereinafter jointly referred to as CONTRACT PRICE) of:
#
# |3.1.1 Foreign Currency Portion:|A lump sum of: US-Dollars ………………………………|
# |---|---|
# |3.1.2 Local Currency Portion:|A lump sum of: Thai Baht ………………………………|
# |3.1.3 The CONTRACT PRICE made up of the fixed lump sum quoted in Article 3.1.1 and 3.1.2 shall be broken down as follows:| |
#
# |Contract Price|US Dollars|Thai Baht|
# |---|---|---|
# |1 Lump-sum Prices for the following:| | |
# |1.1 Marine Facilities including intake / outfall systems| | |
# |1.2 2 LNG Storage Tanks| | |
# |1.3 Balance of Plant (BOP)| | |
# |1.4 Administration Area| | |
# ...

# %%
# 텍스트로 PDF 추출
# import nest_asyncio

# nest_asyncio.apply()

# from llama_parse import LlamaParse
# from llama_index.core import SimpleDirectoryReader

# parser = LlamaParse(
#     api_key=LLAMAIDX_API_KEY,  # can also be set in your env as LLAMA_CLOUD_API_KEY
#     result_type="text",  # "markdown" and "text" are available
#     verbose=True,
# )

# file_extractor = {".pdf": parser}
# documents = SimpleDirectoryReader(
#     "./data", file_extractor=file_extractor
# ).load_data()

# print(documents[0].text[:1000])
# Out:
# Started parsing the file under job_id d68a24e2-a283-412c-9625-21612d849e6f
#             PTTLNG Nong Fab LNG Receiving Terminal Project
#
#
#                                   Invitation to Bid
#
#
# Engineering, Procurement, Construction and Commissioning (EPCC)
#                                        Services
#
#
#                                         Part B
#                         Form and Conditions of Contract
#
#
#                                 Revision 0, March 2017
#                                                                  ptt
#   TGFs                                                           LNG
# ---
#                                                          PTTLNG Nong Fab LNG Receiving Terminal Project
#                                                                                       Invitation to Bid EPCC Services
#                                                                             Part B, Form and Conditions of Contract
# ...

# %%
# Out:
# The CONTRACTOR is responsible for paying if material costs exceed the contractual provisions.

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex
from llama_index.core import Settings

# for the purpose of this example, we will use the small model embedding and gpt3.5
embed_model = OpenAIEmbedding(model="text-embedding-3-small")
llm = OpenAI(model="gpt-3.5-turbo-0125")

Settings.llm = llm

# %%
# Vanilla Approach - Parse the Policy with LlamaParse into Markdown

from llama_parse import LlamaParse

documents = LlamaParse(result_type="markdown").load_data("data/Part B - Form and Conditions of Contract_29032017.pdf")
print(documents[0].text[0:1000])
# Out:
# Started parsing the file under job_id 465c46a3-2c5b-4524-9bf0-271ac3646ec1
# # PTTLNG Nong Fab LNG Receiving Terminal Project
#
# # Invitation to Bid
#
# # Engineering, Procurement, Construction and Commissioning (EPCC) Services
#
# # Part B Form and Conditions of Contract
#
# Revision 0, March 2017
# ---
# # PTTLNG Nong Fab LNG Receiving Terminal Project Invitation to Bid EPCC Services Part B, Form and Conditions of Contract Rev. 0, Mar. 2017
#
# # Part B Form and Conditions of Contract
#
# # INDEX
#
# |ARTICLE 1|DEFINITIONS|
# |---|---|
# |ARTICLE 2|SCOPE OF WORK|
# |ARTICLE 3|CONTRACT PRICE|
# |ARTICLE 4|TERMS OF PAYMENT|
# |ARTICLE 5|CHANGES IN THE WORK|
# |ARTICLE 6|TAXES AND DUTIES|
# |ARTICLE 7|PERFORMANCE SECURITY|
# |ARTICLE 8|REMUNERATION|
# |ARTICLE 9|INDEPENDENT CONTRACTOR|
# |ARTICLE 10|INFORMATION PROVIDED BY PTTLNG|
# |ARTICLE 11|PTTLNG PARTICIPATION AND APPROVALS|
# |ARTICLE 12|WORK PROGRAMME AND COORDINATION PROCEDURE|
# |ARTICLE 13|PROCUREMENT|
# ...

# %%
# Markdown Element Node Parser
